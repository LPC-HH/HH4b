# %%
import numpy as np
import pandas as pd
import vector
import os

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# mplhep for CMS-style plots
import mplhep as hep

plt.style.use(hep.style.CMS)
hep.style.use("CMS")
formatter = mticker.ScalarFormatter(useMathText=True)
formatter.set_powerlimits((-3, 3))
plt.rcParams.update({"font.size": 16})

# %%
# set up directory to save plots
plot_dir = "../../../plots/SensitivityStudy/11Sep23/"
_ = os.system(f"mkdir -p {plot_dir}")

# %%
events = pd.read_parquet(
    "/eos/uscms/store/user/rkansal/bbbb/skimmer/23Aug17/2022/GluGlutoHHto4B_kl-1p00_kt-1p00_c2-0p00_TuneCP5_13p6TeV_TSG/parquet/out_0.parquet"
    #"../../../0-1.parquet"
    # "/eos/uscms/store/user/cmantill/bbbb/matching/Aug8/2022/GluGlutoHHto4B_kl-1p00_kt-1p00_c2-0p00_TuneCP5_13p6TeV_TSG/parquet"
)

# %%
def make_vector(events: pd.DataFrame, obj: str):
    """Create a ``vector`` object from the columns of the dataframe"""
    mstring = "Msd" if obj == "ak8FatJet" else "Mass"

    return vector.array(
        {
            "pt": events[f"{obj}Pt"],
            "phi": events[f"{obj}Phi"],
            "eta": events[f"{obj}Eta"],
            "M": events[f"{obj}{mstring}"],
        }
    )

# %%
fatjets = make_vector(events, "ak8FatJet")
jets = make_vector(events, "ak4Jet")

# %% [markdown]
# ### Plots

# %%
def plot_multi_obj_hist(
    vals: np.ndarray, bins: np.ndarray, obj_label: str, xlabel: str, filename: str
):
    fig, ax = plt.subplots(figsize=(10, 8))
    for i in range(vals.shape[1]):
        ax.hist(vals[:, i].reshape(-1), bins, histtype="step", label=f"{obj_label} {i + 1}")

    ax.legend()
    ax.set_xlabel(xlabel)
    ax.set_ylabel("Number of Events")
    hep.cms.label("Work in Progress", year="2023", com="13.6", ax=ax)
    plt.savefig(f"{plot_dir}/{filename}.pdf", bbox_inches="tight")
    plt.show()
#
#def plot_multi_obj_scatter(
#      vals: np.ndarray, bins: np.ndarray, obj_label: str, xlabel: str, filename: str
#):
#    fig, ax = plt.subplots(figsize=(10, 8))
#    for i in range(vals.shape[1]):
#        ax.scatter(vals[:,i

# %%
plot_multi_obj_hist(
    fatjets.pt, np.linspace(0, 1000, 42), "AK8 Jet", r"AK8 Jet $p_T$ (GeV)", "ak8jetpt"
)
#plot_multi_obj_hist(
#    jets.pt, np.linspace(0, 1000, 21), "AK4 Jet", r"AK4 Jet $p_T$ (GeV)", "ak4jetpt"
#)

# %%
plot_multi_obj_hist(
    fatjets.phi, np.linspace(-4, 4, 21), "AK8 Jet", r"AK8 Jet $\phi$ (GeV)", "ak8jetphi"
)
#plot_multi_obj_hist(
#    jets.phi, np.linspace(-4, 4, 21), "AK4 Jet", r"AK4 Jet $\phi$ (GeV)", "ak4jetpphi"
#)
plot_multi_obj_hist(
    fatjets.eta, np.linspace(-2.5, 2.5, 21), "AK8 Jet", r"AK8 Jet $\eta$ (GeV)", "ak8jeteta"
)
#plot_multi_obj_hist(
#    jets.eta, np.linspace(-2.5, 2.5, 21), "AK4 Jet", r"AK4 Jet $\eta$ (GeV)", "ak4jeteta"
#)
plot_multi_obj_hist(
    fatjets.M, np.linspace(0, 300, 21), "AK8 Jet", r"AK8 Jet $M$ (GeV)", "ak8jetM"
)
#plot_multi_obj_hist(
#    jets.M, np.linspace(0, 300, 21), "AK4 Jet", r"AK4 Jet $M$ (GeV)", "ak4jetM"
#)

# %%
# Out:
# [779.19921875 314.5368042  306.99267578 175.75109863  50.02258682
#   29.81344414]

# %%
jets.shape
# Out:
# (51, 6)
